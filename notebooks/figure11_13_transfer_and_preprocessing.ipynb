# %% [markdown]
# # Figures 11–13 — transfer grid, raw vs preprocessed, transfer gap
#
# Runs `scripts/plot_results_figures_11_13.py`:
#
# - **Figure 11:** `figure11_transfer_grid_roc_auc_cnn_virchow`
# - **Figure 12:** `figure12_cnn_raw_vs_preprocessed_roc_recall`
# - **Figure 13:** `figure13_transfer_gap_roc_auc_by_origin`

# %%
import runpy
from pathlib import Path

REPO = Path.cwd().resolve()
if not (REPO / "scripts").is_dir():
    REPO = REPO.parent
runpy.run_path(str(REPO / "scripts" / "plot_results_figures_11_13.py"), run_name="__main__")
