# %% [markdown]
# # Figures 7–10 — stain benchmark, confusion matrices, error pools
#
# Runs `scripts/plot_results_figures_7_10.py`:
#
# - **Figure 7:** `reports/figures/figure7_stain_benchmark_metrics.{png,pdf}` (replaces Table 8 in Results)
# - **Figure 8:** `figure8_virchow_confusion_matrices_c1_c4` (replaces Table 16)
# - **Figure 9:** `figure9_cnn_confusion_matrices_preprocessed` (replaces Table 11)
# - **Figure 10:** `figure10_qualitative_error_pools_c1_c4` (replaces Table 23)

# %%
import runpy
from pathlib import Path

REPO = Path.cwd().resolve()
if not (REPO / "scripts").is_dir():
    REPO = REPO.parent

runpy.run_path(str(REPO / "scripts" / "plot_results_figures_7_10.py"), run_name="__main__")
